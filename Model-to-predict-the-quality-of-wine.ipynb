# %% [markdown]
# # Loading the dataset and data analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("winequality-red.csv")

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.rename(columns = {
    'fixed acidity' : 'Fixed-acidity',
    'volatile acidity': 'Volatile-acidity',
    'citric acid' : 'Citric-acid',
    'residual sugar': 'Residual-sugar',
    'chlorides': 'Chlorides',
    'free sulfur dioxide': 'Free-sulfur-dioxide',
    'total sulfur dioxide': 'Total-sulfur-dioxide',
    'density': 'Density',
    'pH': 'pH',
    'sulphates': 'Sulphates',
    'alcohol': 'Alcohol',
    'quality': 'Quality'
})
# Out:
#       Fixed-acidity  Volatile-acidity  Citric-acid  Residual-sugar  Chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
#plotting the boxplot and the scatter plot for each metrics

fig, ax = plt.subplots(11, 2, figsize=(15, 45))
plt.subplots_adjust(hspace = 0.5)

for i in range(11) :
    # AX 1
    sns.boxplot(x=df.columns[i], data=df, ax=ax[i, 0])
    # Ax 2
    sns.scatterplot(x=df.columns[i], y='quality', data=df, hue='quality', ax=ax[i, 1])

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
a = df.groupby('quality', as_index=False).mean()
a.columns[0]
# Out:
# 'quality'

# %%
# plotting the different metrics for quality vs all other columns in the table 
    
for i in a.columns[1:]:
    plt.hist2d(x=a['quality'], y=a[i], cmap=plt.cm.Blues)
    plt.colorbar(label='Counts')
    plt.xlabel('Quality')
    plt.ylabel(i)
    plt.title(f'Histogram of Quality vs {i}')
    plt.show()

# %%
#plotting scatter plot by quality counts

import matplotlib.pyplot as plt
import pandas as pd


count = df.groupby('quality').apply(lambda x: x['sulphates'].count()).reset_index(name='Count')
plt.scatter(x=count['quality'], y=count['Count'])
for i, txt in enumerate(count['Count']):
    plt.annotate(txt, (count['quality'][i], count['Count'][i]), 
                 textcoords="offset points", xytext=(0,10), ha='center')

plt.xlabel('Quality')
plt.ylabel('Count of Quality')
plt.title('Number of quality')
plt.show()

# %% [markdown]
# ### Cleaning the dataset

# %%
#checking the null values for the dataset

df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
corr = df.corr()
# cmap = sns.diverging_palette(-1, 1, s=100, l=50, n=15, center="dark", as_cmap=True)
plt.figure(figsize=(9, 6))
sns.heatmap(corr, annot=True, fmt='.2f', linewidth=0.5, cmap='Purples', mask=np.triu(corr))
plt.show()
# Out:
# /Users/asheshlalshrestha/anaconda3/lib/python3.11/site-packages/seaborn/matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)
